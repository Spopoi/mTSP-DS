# %%
from core.Customer import Customer
from core.DroneStation import DroneStation

from core.Location import rand_location
from core.Location import Location
from core.Depot import Depot
from TourUtils import plotNodes

# %% [markdown]
# Print Depot plot:

# %%
v = [Depot(index=0,location=Location(0,0))]
last_node = [Depot(index=1, location=Location(0,0))]
plotNodes(v + last_node, 10)

# %%
for i in range(10):
    v.append(Customer(i+1, rand_location(20)))
plotNodes(v + last_node, 50)

# %%
for j in range(3):
    v.append(DroneStation(j+11, rand_location(20),2))
plotNodes(v + last_node,10)
